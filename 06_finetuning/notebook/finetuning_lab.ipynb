# %% [markdown]
# # finetuning Lab
#
# **說明：** 請先閱讀同目錄的 README.md 和 .py 檔案，再開始執行這個 notebook。
#
# > 設定好 .env 中的 API key 後開始執行

# %%
import os, json, sys
sys.path.insert(0, '..')
from dotenv import load_dotenv
load_dotenv('../.env')
print('Ready. API key set:', bool(os.getenv('OPENAI_API_KEY')))

# %% [markdown]
# ## 主要實驗
#
# 按照 README.md 中的執行順序，在這裡執行並記錄觀察。

# %%
# TODO: 從對應的 .py 檔案 import 函式並實驗
# 範例：
# from basic_rag import build_rag_pipeline
# query_engine = build_rag_pipeline('data/sample.pdf')
# result = query_engine.query('What is the synthesis temperature?')
# print(result)

# %% [markdown]
# ## 觀察記錄
#
# 在這裡記錄你的實驗結果和心得：
#
# - **什麼有效：**
# - **什麼無效：**
# - **值得繼續探索的方向：**

# %% [markdown]
# ## 練習題
#
# 1. 用你自己的材料科學論文段落測試
# 2. 嘗試修改參數，觀察效果變化
# 3. 把有趣的案例存下來作為 fine-tuning 訓練資料

# %%
# 你的實驗
